# %%
import time
# Should be more gradual by 1 or 2 "."
newLine = " "*200
elements = [
    {
        "text": "Hello World",
        "time": 5,
    },
    {
        "text": "Hello World.",
        "time": 3,
    },
    {
        "text": "Hello World..",
        "time": 2,
    },
    {
        "text": "Hello World...",
        "time": 1,
    },
    {
        "text": "Hello World....",
        "time": .4,
    },
    {
        "text": "Hello World.....",
        "time": .2,
    },
    {
        "text": "Hello World......",
        "time": .2,
    },
    {
        "text": "Hello World.......",
        "time": .2,
    },
    {
        "text": "Hello World........",
        "time": .2
    },
    {
        "text": "Hello World.........",
        "time": .2
    },
    {
        "text": "Hello World.........;" + "....................",
        "time": .4
    },
    {
        "text": "Hello World.........;" + "....................;" + "....................",
        "time": .4
    },
    {
        "text": "Hello World.........;" +"....................;" + "....................;" + "....................",
        "time": .4
    },
    {
        "text": "Hello World.........;" + "....................;" + "....................;" + "....................;" + "....................", #9 Period(s)
        "time": .4
    },
    {
        "text" : "Hello World.........;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................", #9 Period(s)
        "time": .4
    },
    {
        "text" : "Hello World.........;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................", #9 Period(s)
        "time": .4
    },
    {
        "text" : "Hello World.........;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................", #9 Period(s)
        "time": .4
    },
    {
        "text" : "Hello World.........;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................", #9 Period(s)
        "time": .4
    },
    {
        "text" : "Hello World.........;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................", #9 Period(s)
        "time": .4
    },
    {
        "text" : "Hello World.........;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................", #9 Period(s)
        "time": .4
    },
    {
        "text" : "Hello World.........;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................", #9 Period(s)
        "time": .4
    },
    {
        "text" : "Hello World.........;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................", #9 Period(s)
        "time": .4
    },
    {
        "text" : "Hello World.........;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................", #9 Period(s)
        "time": .4
    },
    {
        "text" : "Hello World.........;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................", #9 Period(s)
        "time": .4
    },
    {
        "text" : "Hello World.........;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................", #9 Period(s)
        "time": .4
    },
    {
        "text" : "Hello World.........;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................", #9 Period(s)
        "time": .4
    },
    {
        "text" : "Hello World.........;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................", #9 Period(s)
        "time": .4
    },
    {
        "text" : "Hello World.........;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................", #9 Period(s)
        "time": .4
    },
    {
        "text" : "Hello World.........;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................", #9 Period(s)
        "time": .4
    },
    {
        "text" : "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................;" + "....................", #9 Period(s)
        "time": .4
    }] 
# Just seperate new lines by 1 character, the ";"
class file:
    def question(lines):
        userResponce = input("Are you ready for more? Y/N: ")
        if userResponce == "Y":
            part2 = True
            print(lines)
        elif userResponce == "N":
            part2 = True
            print(lines)
        else:
            print("Invalid Responce", end = "\r")
            file.question()
    def execute(string):
        lines = ""
        Text = ""
        if(string == "Hello World.py"):
            # Set Start to 0 in final showcase
            for x in range(0, len(elements)):
                Text = elements[x]["text"]
                Text = Text.split(";")
                lines = str(len(Text[len(Text) - 1])) + "x" + str(len(Text)) + ":" + newLine
                for yCt in range(0, len(Text)):
                    lines += str(Text[yCt] + newLine)
                print(lines, end="\r")
                time.sleep(elements[x]["time"])
            
            theLines = ""
            for b in range(0, len(Text) + 4):
                #Adds 1 for x by y, 2 for extra newlines
                if b < len(Text) + 4:
                    theLines += "" + newLine
                else:
                    theLines += ""
            lines.replace(newLine, "*")
            print(theLines, end = "\r")
            file.question(lines)
        else:
            print("Error: Cannnot Find File")
file.execute("Hello World.py")
# Out:
#   Cell In[5], line 125
#     ​]
#     ^
# SyntaxError: invalid character in identifier
